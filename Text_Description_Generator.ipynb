# %% [markdown]
# <a href="https://colab.research.google.com/github/hamdjalil/SE_admin/blob/main/Text_Description_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
from glob import glob
import shutil

# %%
datasets = '/content/gdrive/MyDrive/ML/Code/DeepFashion_Try_On_v1/DeepFashion_Try_On/Datasets'
datasets
# Out:
# '/content/gdrive/MyDrive/ML/Code/DeepFashion_Try_On_v1/DeepFashion_Try_On/Datasets'

# %%
os.chdir(datasets)

# %%
ls
# Out:
#  8.0_8.1/                            'High Res'/
#  8.0_8.1_SIMPLE/                      High_Res/
#  close_colors5/                      'High Res Mix.zip'
#  color_variation/                     LongAndShortDress/
#  color_variation_dummy_to_dummy/     'Long Length Dresses'/
#  Complicated_Level_0/                'Low Res Mix'/
# 'Complicated Level 0 and 1'/         'Low Res Mix.zip'
#  Complicated_Level_0_Single_Colors/   Misc/
# 'contrast colors'/                    Mixed/
# 'Dress 1 (Short Length)'/             Mixed_Level_0/
#  Dress_7/                             Mixed.zip
#  Dress_7.zip                          unfiltered/
#  Dress8_other_Res.zip                 unfiltered_new/

# %%
dataset =  '../Datasets/Low Res Mix/experiment_1/train_img'
train = glob(dataset+"/**/*", recursive = True)

print("Train Data Size", len(ds))

dataset =  '../Datasets/Low Res Mix/experiment_1/test_img'
test = glob(dataset+"/**/*", recursive = True)

print("Test Data Size", len(testset))
# Out:
# Train Data Size 1284
# Test Data Size 352

# %%
newplace = '/content/gdrive/MyDrive/ML/Code/DeepFashion_Try_On_v1/DeepFashion_Try_On/Datasets/Complicated_Level_0/Dress8_dummy_transformer/'
newplace
# Out:
# '/content/gdrive/MyDrive/ML/Code/DeepFashion_Try_On_v1/DeepFashion_Try_On/Datasets/Complicated_Level_0/Dress8_dummy_transformer/'

# %%
new_loc = '/content/gdrive/MyDrive/ML/Code/DeepFashion_Try_On_v1/DeepFashion_Try_On/Datasets/Complicated_Level_0/Dress8_dummy_transformer/experiment_0/train_img2'

# %%
for i in range(0, len(train)):
  shutil.copy(train[i], new_loc)

# %%
for i in range(0, len(test)):
  shutil.copy(test[i], new_loc)

# %%
new_data = glob(new_loc+"/*", recursive = True)
len(new_data)
# Out:
# 1636

# %%
folder = '/content/gdrive/MyDrive/ML/Code/DeepFashion_Try_On_v1/DeepFashion_Try_On/Datasets/Complicated_Level_0/Dress8_dummy_transformer/experiment_0/train_img2/'
for i in new_data:
  print(i)
  color = i.split('/')[-1].split('_')[1]
  dress_type = i.split('/')[-1].split('_')[0]
  filename = i.split('/')[-1].split('.')[0] + '.txt'
  print(filename)
  f = open(folder+filename,"w+")
  if(dress_type == 'dress17' ):
    text = color + ' long none_embroidery shirt red slim none_embroidery trouser'  
  if(dress_type == 'dress8' ):
    text = color + ' medium none_embroidery shirt peach straight none_embroidery trouser'
  if(dress_type == 'dress7' ):
    text = color + ' long frontal_embroidery shirt red slim none_embroidery trouser' 
  if(dress_type == 'dress3' ):
    text = color + ' short dotted_embroidery shirt multi loose floral_embroidery trouser' 
  if(dress_type == 'dress1' ):
    text = color + ' short side_embroidery shirt yellow wide bottom_embroidery trouser' 
  if(dress_type == 'dress14' ):
    text = color + ' long none_embroidery shirt purple slim none_embroidery trouser' 
  if(dress_type == 'dress4' ):
    text = color + ' long border_embroidery shirt purple slim none_embroidery trouser' 
  if(dress_type == 'dress2' ):
    text = color + ' medium arm_embroidery shirt black straight dotted_pattern trouser' 
  if(dress_type == 'dress12' ):
    text = color + ' medium none_embroidery shirt black straight dotted_pattern trouser' 
  if(dress_type == 'dress19' ):
    text = color + ' slim_long none_embroidery shirt grey skinny none_embroidery trouser' 
  if(dress_type == 'dress9' ):
    text = color + ' slim_long neck_embroidery shirt grey skinny none_embroidery trouser' 
  if(dress_type == 'dress13' ):
    text = color + ' medium none_embroidery shirt multi loose floral_embroidery trouser' 
  
  print(text)
  f.write(text)
  f.close()
# Out:
# /content/gdrive/MyDrive/ML/Code/DeepFashion_Try_On_v1/DeepFashion_Try_On/Datasets/Complicated_Level_0/Dress8_dummy_transformer/experiment_0/train_img2/dress17_color11_orignal_1.jpg
# dress17_color11_orignal_1.txt
# color11 long none_embroidery shirt red slim none_embroidery trouser
# /content/gdrive/MyDrive/ML/Code/DeepFashion_Try_On_v1/DeepFashion_Try_On/Datasets/Complicated_Level_0/Dress8_dummy_transformer/experiment_0/train_img2/dress8_color10_flipped_0.jpg
# dress8_color10_flipped_0.txt
# color10 medium none_embroidery shirt peach straight none_embroidery trouser
# /content/gdrive/MyDrive/ML/Code/DeepFashion_Try_On_v1/DeepFashion_Try_On/Datasets/Complicated_Level_0/Dress8_dummy_transformer/experiment_0/train_img2/dress7_color10_flipped_0.jpg
# dress7_color10_flipped_0.txt
# color10 long frontal_embroidery shirt red slim none_embroidery trouser
# ...

# %%
len(new_data)
# Out:
# 1636
